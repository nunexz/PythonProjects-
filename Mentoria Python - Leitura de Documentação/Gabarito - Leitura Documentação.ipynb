# %% [markdown]
# #### Bibliotecas

# %%
# pandas -> analise de dados
# getting started
# quickstart
import pandas as pd

df = pd.DataFrame(
    {
        "Name": [
            "Braund, Mr. Owen Harris",
            "Allen, Mr. William Henry",
            "Bonnell, Miss. Elizabeth",
        ],
        "Age": [22, 35, 58],
        "Sex": ["male", "male", "female"],
})


display(df)
print(df["Age"])
# pd.DataFrame
# pd.DataFrame -> recebe um dicionário como parâmetro e cria a tabela a partir do dicionário
# Out:
#                        Name  Age     Sex
# 0   Braund, Mr. Owen Harris   22    male
# 1  Allen, Mr. William Henry   35    male
# 2  Bonnell, Miss. Elizabeth   58  female
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
ages = pd.Series([22, 35, 58], name="Age")

print(df["Age"].max())
print(ages.max())
# Out:
# 58
# 58

# %%
# requests
#PyPI - Project Links na barra lateral
#Read the docs -> documentação
# Github -> ReadMe

# %% [markdown]
# #### Funções Específicas

# %%
# datas no pandas
import pandas as pd

tabela = pd.read_excel("Contratos.xlsx")
tabela['Data Pagamento'] = pd.to_datetime(tabela['Data Pagamento'], format='%d/%m/%Y')
tabela['Data Pagamento 2'] = pd.to_datetime(tabela['Data Pagamento 2'], format='%m-%d-%y')
print(tabela.dtypes)


display(tabela)
# Out:
# Cliente                     object
# Data Pagamento      datetime64[ns]
# Data Pagamento 2    datetime64[ns]
# dtype: object
#     Cliente Data Pagamento Data Pagamento 2
# 0    Fulano     2022-09-22       2022-09-22
# 1  Beltrano     2022-04-17       2022-04-17
# 2   Ciclano     2022-02-21       2022-02-21
# 3      Lira     2022-12-27       2022-12-27
# 4     Julia     2022-02-01       2022-02-01
# 5    Marcus     2022-07-08       2022-07-08
# 6    Amanda     2022-09-28       2022-09-28
# 7   Larissa     2022-05-28       2022-05-28
# 8      Alon     2022-10-06       2022-10-06

# %%
# funcao merge do pandas

emails = pd.read_excel("Emails.xlsx")
tabela = tabela.merge(emails, left_on="Cliente", right_on="Nome")
display(tabela)
# Out:
#     Cliente Data Pagamento Data Pagamento 2      Nome               Email
# 0    Fulano     2022-09-22       2022-09-22    Fulano    fulano@gmail.com
# 1  Beltrano     2022-04-17       2022-04-17  Beltrano  beltrano@gmail.com
# 2   Ciclano     2022-02-21       2022-02-21   Ciclano   ciclano@gmail.com
# 3      Lira     2022-12-27       2022-12-27      Lira      lira@gmail.com
# 4     Julia     2022-02-01       2022-02-01     Julia     julia@gmail.com
# 5    Marcus     2022-07-08       2022-07-08    Marcus    marcus@gmail.com
# 6    Amanda     2022-09-28       2022-09-28    Amanda    amanda@gmail.com
# 7   Larissa     2022-05-28       2022-05-28   Larissa   larissa@gmail.com
# 8      Alon     2022-10-06       2022-10-06      Alon      alon@gmail.com

# %%
# funcao datetime

from datetime import datetime

hoje = datetime(2022, 12, 15)
print(hoje)
# Out:
# 2022-12-15 00:00:00

# %% [markdown]
# #### APIs

# %%
# documentação de APIs cada uma é diferente da outra, 
# vejam o módulo de API que eu faço vários exemplos lá

# autenticação

# exemplo sandbox https://dadosabertos.bcb.gov.br/dataset/dinheiro-em-circulao

# exemplo documentação: https://www.alphavantage.co/

import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY_ADJUSTED&symbol=IBM&apikey=dfsdhfsiufhsfuishfis'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Meta Data': {'1. Information': 'Weekly Adjusted Prices and Volumes', '2. Symbol': 'IBM', '3. Last Refreshed': '2022-09-22', '4. Time Zone': 'US/Eastern'}, 'Weekly Adjusted Time Series': {'2022-09-22': {'1. open': '126.4900', '2. high': '128.0600', '3. low': '124.4100', '4. close': '125.3100', '5. adjusted close': '125.3100', '6. volume': '14246971', '7. dividend amount': '0.0000'}, '2022-09-16': {'1. open': '130.3300', '2. high': '130.9900', '3. low': '123.8300', '4. close': '127.2700', '5. adjusted close': '127.2700', '6. volume': '27107187', '7. dividend amount': '0.0000'}, '2022-09-09': {'1. open': '127.8000', '2. high': '129.4900', '3. low': '126.2800', '4. close': '129.1900', '5. adjusted close': '129.1900', '6. volume': '12004834', '7. dividend amount': '0.0000'}, '2022-09-02': {'1. open': '129.9900', '2. high': '131.4200', '3. low': '127.2400', '4. close': '127.7900', '5. adjusted close': '127.7900', '6. volume': '15086608', '7. dividend amount': '0.0000'}, '2022-08-26': {'1. open': '137.6500', '2. high': '137.8500', '3. low': '130.3400', '4. close': '130.3800', '5. adjusted close': '130.3800', '6. volume': '16982107', '7. dividend amount': '0.0000'}, '2022-08-19': {'1. open': '132.9600', '2. high': '139.3400', '3. low': '132.2400', '4. close': '138.3700', '5. adjusted close': '138.3700', '6. volume': '17105977', '7. dividend amount': '0.0000'}, '2022-08-12': {'1. open': '133.1000', '2. high': '134.0900', '3. low': '129.1200', '4. close': '134.0100', '5. adjusted close': '134.0100', '6. volume': '17254110', '7. dividend amount': '1.6500'}, '2022-08-05': {'1. open': '130.7500', '2. high': '132.8620', '3. low': '130.5100', '4. close': '132.4800', '5. adjusted close': '130.8129', '6. volume': '17400572', '7. dividend amount': '0.0000'}, '2022-07-29': {'1. open': '128.4400', '2. high': '131.0000', '3. low': '127.5800', '4. close': '130.7900', '5. adjusted close': '129.1442', '6. volume': '22223785', '7. dividend amount': '0.0000'}, '2022-07-22': {'1. open': '140.1500', '2. high': '140.3100', '3. low': '125.1300', '4. close': '128.2500', '5. adjusted close': '126.6361', '6. volume': '66246811', '7. dividend amount': '0.0000'}, '2022-07-15': {'1. open': '140.6200', '2. high': '141.8700', '3. low': '135.0200', '4. close': '139.9200', '5. adjusted close': '138.1593', '6. volume': '21089228', '7. dividend amount': '0.0000'}, '2022-07-08': {'1. open': '139.9700', '2. high': '141.3250', '3. low': '135.2700', '4. close': '140.4700', '5. adjusted close': '138.7023', '6. volume': '16229131', '7. dividend amount': '0.0000'}, '2022-07-01': {'1. open': '142.2600', '2. high': '144.1550', '3. low': '139.2600', '4. close': '141.1200', '5. adjusted close': '139.3442', '6. volume': '21052787', '7. dividend amount': '0.0000'}, '2022-06-24': {'1. open': '135.9000', '2. high': '142.3700', '3. low': '135.9000', '4. close': '142.0600', '5. adjusted close': '140.2723', '6. volume': '23921844', '7. dividend amount': '0.0000'}, '2022-06-17': {'1. open': '133.9700', '2. high': '138.4500', '3. low': '132.8500', '4. close': '135.0200', '5. adjusted close': '133.3209', '6. volume': '34055621', '7. dividend amount': '0.0000'}, '2022-06-10': {'1. open': '142.9800', '2. high': '144.7300', '3. low': '135.2500', '4. close': '136.1900', '5. adjusted close': '134.4762', '6. volume': '18914084', '7. dividend amount': '0.0000'}, '2022-06-03': {'1. open': '138.2000', '2. high': '142.5794', '3. low': '136.8100', '4. close': '141.1800', '5. adjusted close': '139.4034', '6. volume': '19861566', '7. dividend amount': '0.0000'}, '2022-05-27': {'1. open': '129.5000', '2. high': '139.7394', '3. low': '129.4200', '4. close': '139.2700', '5. adjusted close': '137.5174', '6. volume': '19618090', '7. dividend amount': '0.0000'}, '2022-05-20': {'1. open': '133.1000', '2. high': '138.3700', '3. low': '125.8000', '4. close': '128.4800', '5. adjusted close': '126.8632', '6. volume': '27360441', '7. dividend amount': '0.0000'}, '2022-05-13': {'1. open': '134.4100', '2. high':  ...
