# %% [markdown]
# #### Bibliotecas

# %%
# pandas
#quando for procurar uma biblioteca que eu não conheço, pesquisar no google o nome da biblioteca e python do lado
# procurar na página por getting started ou quickstart
#se não encontrar isso, vai no user guide (ou user guide dentro do getting started)
import pandas as pd

df = pd.DataFrame(
    {
        "Name": [
            "Braund, Mr. Owen Harris",
            "Allen, Mr. William Henry",
            "Bonnell, Miss. Elizabeth",
        ],
        "Age": [22, 35, 58],
        "Sex": ["male", "male", "female"],
    }
)


ages = pd.Series([22, 35, 58], name="Age")

ages
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
# requests
#PyPI - project links na barra lateral
#read the docs -> documentação
#Github -> ReadMe

import pandas as pd
import datetime as dt

tabela = pd.read_excel('Contratos.xlsx')

tabela['Data Pagamento'] = pd.to_datetime(tabela['Data Pagamento'])
tabela['Data Pagamento 2'] = pd.to_datetime(tabela['Data Pagamento 2'])
print(tabela.dtypes)

display(tabela)
# Out:
# Cliente                     object
# Data Pagamento      datetime64[ns]
# Data Pagamento 2    datetime64[ns]
# dtype: object
# C:\Users\User\AppData\Local\Temp\ipykernel_18332\936702133.py:11: UserWarning: Parsing '22/09/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   tabela['Data Pagamento'] = pd.to_datetime(tabela['Data Pagamento'])
# C:\Users\User\AppData\Local\Temp\ipykernel_18332\936702133.py:11: UserWarning: Parsing '17/04/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   tabela['Data Pagamento'] = pd.to_datetime(tabela['Data Pagamento'])
# C:\Users\User\AppData\Local\Temp\ipykernel_18332\936702133.py:11: UserWarning: Parsing '21/02/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   tabela['Data Pagamento'] = pd.to_datetime(tabela['Data Pagamento'])
# ...

# %% [markdown]
# #### Funções Específicas

# %%
# datas no pandas


emails = pd.read_excel('Emails.xlsx')

tabela = tabela.merge(emails, left_on='Cliente', right_on='Nome')

display(tabela)
# Out:
#     Cliente Data Pagamento Data Pagamento 2      Nome               Email
# 0    Fulano     2022-09-22       2022-09-22    Fulano    fulano@gmail.com
# 1  Beltrano     2022-04-17       2022-04-17  Beltrano  beltrano@gmail.com
# 2   Ciclano     2022-02-21       2022-02-21   Ciclano   ciclano@gmail.com
# 3      Lira     2022-12-27       2022-12-27      Lira      lira@gmail.com
# 4     Julia     2022-01-02       2022-02-01     Julia     julia@gmail.com
# 5    Marcus     2022-08-07       2022-07-08    Marcus    marcus@gmail.com
# 6    Amanda     2022-09-28       2022-09-28    Amanda    amanda@gmail.com
# 7   Larissa     2022-05-28       2022-05-28   Larissa   larissa@gmail.com
# 8      Alon     2022-06-10       2022-10-06      Alon      alon@gmail.com

# %%
# funcao datetime
# Out:
#     Cliente Data Pagamento Data Pagamento 2      Nome               Email
# 0    Fulano     2022-09-22       2022-09-22    Fulano    fulano@gmail.com
# 1  Beltrano     2022-04-17       2022-04-17  Beltrano  beltrano@gmail.com
# 2   Ciclano     2022-02-21       2022-02-21   Ciclano   ciclano@gmail.com
# 3      Lira     2022-12-27       2022-12-27      Lira      lira@gmail.com
# 4     Julia     2022-01-02       2022-02-01     Julia     julia@gmail.com
# 5    Marcus     2022-08-07       2022-07-08    Marcus    marcus@gmail.com
# 6    Amanda     2022-09-28       2022-09-28    Amanda    amanda@gmail.com
# 7   Larissa     2022-05-28       2022-05-28   Larissa   larissa@gmail.com
# 8      Alon     2022-06-10       2022-10-06      Alon      alon@gmail.com

# %%
# funcao merge do pandas

# %% [markdown]
# #### APIs

# %%
# documentação de APIs cada uma é diferente da outra, 
# vejam o módulo de API que eu faço vários exemplos lá

#APIs tem autenticação

# exemplo sandbox https://dadosabertos.bcb.gov.br/dataset/dinheiro-em-circulao

import requests

# exemplo documentação: https://www.alphavantage.co/

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY_ADJUSTED&symbol=IBM&apikey=demo'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Meta Data': {'1. Information': 'Weekly Adjusted Prices and Volumes', '2. Symbol': 'IBM', '3. Last Refreshed': '2022-12-08', '4. Time Zone': 'US/Eastern'}, 'Weekly Adjusted Time Series': {'2022-12-08': {'1. open': '147.9400', '2. high': '149.1530', '3. low': '146.2900', '4. close': '147.7800', '5. adjusted close': '147.7800', '6. volume': '12267891', '7. dividend amount': '0.0000'}, '2022-12-02': {'1. open': '147.9800', '2. high': '150.0100', '3. low': '145.6700', '4. close': '148.6700', '5. adjusted close': '148.6700', '6. volume': '20066941', '7. dividend amount': '0.0000'}, '2022-11-25': {'1. open': '147.5500', '2. high': '150.4600', '3. low': '146.4500', '4. close': '148.3700', '5. adjusted close': '148.3700', '6. volume': '16271883', '7. dividend amount': '0.0000'}, '2022-11-18': {'1. open': '142.6300', '2. high': '148.3100', '3. low': '142.0000', '4. close': '147.6400', '5. adjusted close': '147.6400', '6. volume': '22034930', '7. dividend amount': '0.0000'}, '2022-11-11': {'1
# ...
